# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")

# %%
cv2.imshow("picture",img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (174, 290, 3)

# %%
print("height",img.shape[0],"pixel")
print("width",img.shape[1],"pixel")
# Out:
# height 174 pixel
# width 290 pixel

# %%
plt.imshow(img)

# %%
plt.imshow(img[:,:,::-1])

# %%
cv2.COLOR_BGR2RGB
# Out:
# 4

# %%
rgb_img=cv2.cvtColor(img,4)
plt.imshow(rgb_img)

# %%
img[40:140,100:300,::]=(197,179,79)
plt.imshow(img[...,::-1])

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")
cv2.imshow("orginal",image)
cv2.waitKey()
gray=cv2.cvtColor(image,0)
cv2.imshow("gray",gray)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\pic1.jpg")
B,G,R=image[10,50]
print(B,G,R)
print(image.shape)
gray_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
print(gray_image[10,50])
print(image.shape)
# Out:
# 237 178 99
# (174, 290, 3)
# 161
# (174, 290, 3)

# %%
R*0.2989+G*0.5870+B*0.1140,0
# Out:
# (161.0951, 0)

# %%
round(R*0.2989+G*0.5870+B*0.1140,0)
# Out:
# 161.0

# %%
image1=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.png",0)
plt.imshow(image1,cmap="gray")

# %%
plt.imshow(image1)

# %%
cv2.imwrite("newPic.jpg",image1)
