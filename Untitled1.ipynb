# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.jfif")
plt.imshow(image[...,::-1])

# %%
crop=image[50:110,50:500]
plt.imshow(crop[...,::-1])

# %%
height,widht=image.shape[:2]
crop=image[height//3:3*height//4,widht//3:3*widht//4]
plt.imshow(crop[...,::-1])

# %%
image1=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.jfif")
b,g,r=cv2.split(image1)
plt.figure(figsize=[12,8])
plt.subplot(141);plt.imshow(r,cmap="gray");plt.title("Red-Channel");
plt.subplot(142);plt.imshow(g,cmap="gray");plt.title("Green-Channel");
plt.subplot(143);plt.imshow(b,cmap="gray");plt.title("Blue-Channel");
plt.subplot(144);plt.imshow(image1[...,::-1]);plt.title("All-Channel");
plt.show()

# %%
merge=cv2.merge([r,g,b])
plt.figure(figsize=[12,8])
plt.subplot(141);plt.imshow(r,cmap="gray");plt.title("Red-Channel");
plt.subplot(142);plt.imshow(g,cmap="gray");plt.title("Green-Channel");
plt.subplot(143);plt.imshow(b,cmap="gray");plt.title("Blue-Channel");
plt.subplot(144);plt.imshow(merge);plt.title("Merge");
plt.show()

# %%
a=[1,3,6]
f=np.zeros_like(a,'uint8')
f
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
image1=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.jpg")
b,g,r=cv2.split(image1)
modify_b=b.astype("int16")+200
modify_b=np.minimum(255,modify_b)
modify_b=modify_b.astype("uint8")
merge=cv2.merge([modify_b,g,r])
plt.figure(figsize=[20,5])
plt.subplot(151);plt.imshow(r,cmap="gray");plt.title("Red-Channel");
plt.subplot(152);plt.imshow(g,cmap="gray");plt.title("Green-Channel");
plt.subplot(153);plt.imshow(modify_b,cmap="gray");plt.title("Blue-Channel");
plt.subplot(154);plt.imshow(merge[...,::-1],cmap="gray");plt.title("mehr Blue-Channel");
plt.subplot(155);plt.imshow(image1[...,::-1],cmap="gray");plt.title("All-Channel");
plt.show()

# %%
image1=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.jpg")
b,g,r=cv2.split(image1)
modify_b=cv2.add(b,150)
merge=cv2.merge([r,g,modify_b])
plt.figure(figsize=[20,5])
plt.subplot(151);plt.imshow(r,cmap="gray");plt.title("Red-Channel");
plt.subplot(152);plt.imshow(g,cmap="gray");plt.title("Green-Channel");
plt.subplot(153);plt.imshow(modify_b,cmap="gray");plt.title("Blue-Channel");
plt.subplot(154);plt.imshow(merge);plt.title("mehr Blue-Channel");
plt.subplot(155);plt.imshow(image1[...,::-1]);plt.title("All-Channel");
plt.show()

# %%
image=cv2.imread(r"C:\\Users\Student\Desktop\pic\x.jpg")
b,g,r=cv2.split(image)
modify_b=b.astype("int16")+200
modify_b=np.minimum(255,modify_b)
modify_b=modify_b.astype("uint8")
merge=cv2.merge([modify_b,g,r])
plt.figure(figsize=[20,5])
plt.subplot(151);plt.imshow(r,cmap="gray");plt.title("red-channel");
plt.subplot(152);plt.imshow(g,cmap="gray");plt.title("grean-channel");
plt.subplot(153);plt.imshow(modify_b,cmap="gray");plt.title("blue-channel");
plt.subplot(154);plt.imshow(merge[...,::-1],cmap="gray");plt.title("blue-channel");
plt.subplot(155);plt.imshow(image[...,::-1],cmap="gray");plt.title("blue-channel");

plt.show()
